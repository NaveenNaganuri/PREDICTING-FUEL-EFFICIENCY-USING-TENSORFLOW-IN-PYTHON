# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

import tensorflow as tf
from tensorflow import keras
from keras import layers

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('auto-mpg.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.shape
# Out:
# (398, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df['horsepower'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
print(df.shape)
df = df[df['horsepower'] != '?']
print(df.shape)
# Out:
# (398, 9)
# (392, 9)

# %%
df['horsepower'] = df['horsepower'].astype(int)
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df.nunique()
# Out:
# mpg             127
# cylinders         5
# displacement     81
# horsepower       93
# weight          346
# acceleration     95
# model year       13
# origin            3
# car name        301
# dtype: int64

# %%
plt.subplots(figsize=(15, 5))
for i, col in enumerate(['cylinders', 'origin']):
    plt.subplot(1, 2, i+1)
    x = df.groupby(col).mean()['mpg']
    x.plot.bar()
    plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 8))
sb.heatmap(df.corr() > 0.9,
           annot=True,
           cbar=False)
plt.show()

# %%
df.drop('displacement',
        axis=1,
        inplace=True)

# %%
from sklearn.model_selection import train_test_split
features = df.drop(['mpg', 'car name'], axis=1)
target = df['mpg'].values

X_train, X_val, \
    Y_train, Y_val = train_test_split(features, target,
                                      test_size=0.2,
                                      random_state=22)
X_train.shape, X_val.shape
# Out:
# ((313, 6), (79, 6))

# %%
AUTO = tf.data.experimental.AUTOTUNE

train_ds = (
    tf.data.Dataset
    .from_tensor_slices((X_train, Y_train))
    .batch(32)
    .prefetch(AUTO)
)

val_ds = (
    tf.data.Dataset
    .from_tensor_slices((X_val, Y_val))
    .batch(32)
    .prefetch(AUTO)
)

# %%
model = keras.Sequential([
    layers.Dense(256, activation='relu', input_shape=[6]),
    layers.BatchNormalization(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1, activation='relu')
])

# %%
model.compile(
    loss='mae',
    optimizer='adam',
    metrics=['mape']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               1792
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dropout (Dropout)           (None, 256)               0
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 69889 (273.00 KB)
# Trainable params: 68865 (269.00 KB)
# Non-trainable params: 1024 (4.00 KB)
# _________________________________________________________________

# %%
history = model.fit(train_ds,
                    epochs=50,
                    validation_data=val_ds)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 2s 25ms/step - loss: 21.4609 - mape: 85.4453 - val_loss: 40.5981 - val_mape: 247.7877
# Epoch 2/50
# 10/10 [==============================] - 0s 6ms/step - loss: 20.2033 - mape: 78.1201 - val_loss: 28.0197 - val_mape: 172.3698
# Epoch 3/50
# 10/10 [==============================] - 0s 6ms/step - loss: 19.4821 - mape: 74.4229 - val_loss: 15.9325 - val_mape: 90.4156
# Epoch 4/50
# 10/10 [==============================] - 0s 5ms/step - loss: 18.9008 - mape: 71.5148 - val_loss: 12.0675 - val_mape: 58.2199
# Epoch 5/50
# 10/10 [==============================] - 0s 6ms/step - loss: 18.2357 - mape: 68.0838 - val_loss: 10.7733 - val_mape: 45.3696
# Epoch 6/50
# 10/10 [==============================] - 0s 7ms/step - loss: 17.6921 - mape: 65.8537 - val_loss: 10.7785 - val_mape: 41.0381
# Epoch 7/50
# 10/10 [==============================] - 0s 6ms/step - loss: 17.0763 - mape: 62.8095 - val_loss: 9.8916 - val_mape: 37.7503
# Epoch 8/50
# 10/10 [==============================] - 0s 6ms/step - loss: 16.4213 - mape: 59.8327 - val_loss: 9.3562 - val_mape: 37.4088
# Epoch 9/50
# 10/10 [==============================] - 0s 6ms/step - loss: 15.9501 - mape: 58.0443 - val_loss: 8.8139 - val_mape: 34.1840
# Epoch 10/50
# 10/10 [==============================] - 0s 6ms/step - loss: 15.2879 - mape: 55.0864 - val_loss: 8.5059 - val_mape: 34.7148
# Epoch 11/50
# 10/10 [==============================] - 0s 7ms/step - loss: 14.6287 - mape: 52.4240 - val_loss: 7.8137 - val_mape: 33.0986
# Epoch 12/50
# 10/10 [==============================] - 0s 7ms/step - loss: 13.8971 - mape: 49.3619 - val_loss: 8.8262 - val_mape: 43.4600
# Epoch 13/50
# 10/10 [==============================] - 0s 7ms/step - loss: 13.3665 - mape: 47.3857 - val_loss: 7.3030 - val_mape: 34.7391
# Epoch 14/50
# 10/10 [==============================] - 0s 6ms/step - loss: 12.7408 - mape: 44.9359 - val_loss: 6.2370 - val_mape: 28.8463
# Epoch 15/50
# 10/10 [==============================] - 0s 6ms/step - loss: 12.1050 - mape: 42.3948 - val_loss: 5.5634 - val_mape: 25.6520
# Epoch 16/50
# 10/10 [==============================] - 0s 6ms/step - loss: 11.7233 - mape: 41.2024 - val_loss: 4.0878 - val_mape: 16.7124
# Epoch 17/50
# 10/10 [==============================] - 0s 6ms/step - loss: 11.1823 - mape: 39.3560 - val_loss: 4.0945 - val_mape: 16.4566
# Epoch 18/50
# 10/10 [==============================] - 0s 6ms/step - loss: 11.1849 - mape: 39.5756 - val_loss: 4.8345 - val_mape: 20.3408
# Epoch 19/50
# 10/10 [==============================] - 0s 6ms/step - loss: 10.8916 - mape: 38.7137 - val_loss: 4.3174 - val_mape: 17.1778
# Epoch 20/50
# 10/10 [==============================] - 0s 5ms/step - loss: 10.6955 - mape: 38.2213 - val_loss: 4.9975 - val_mape: 21.9523
# Epoch 21/50
# 10/10 [==============================] - 0s 6ms/step - loss: 10.3999 - mape: 37.3328 - val_loss: 6.9783 - val_mape: 34.0311
# Epoch 22/50
# 10/10 [==============================] - 0s 6ms/step - loss: 10.2272 - mape: 36.3027 - val_loss: 6.7833 - val_mape: 30.9927
# Epoch 23/50
# 10/10 [==============================] - 0s 6ms/step - loss: 10.1182 - mape: 36.6827 - val_loss: 10.0002 - val_mape: 48.0985
# Epoch 24/50
# 10/10 [==============================] - 0s 7ms/step - loss: 9.6491 - mape: 34.5461 - val_loss: 8.6242 - val_mape: 39.3950
# Epoch 25/50
# 10/10 [==============================] - 0s 6ms/step - loss: 9.2783 - mape: 33.4042 - val_loss: 9.9148 - val_mape: 46.2728
# Epoch 26/50
# 10/10 [==============================] - 0s 5ms/step - loss: 9.1022 - mape: 32.7424 - val_loss: 11.4674 - val_mape: 54.8881
# Epoch 27/50
# 10/10 [==============================] - 0s 6ms/step - loss: 8.6780 - mape: 31.4745 - val_loss: 12.6708 - val_mape: 64.2955
# Epoch 28/50
# 10/10 [==============================] - 0s 7ms/step - loss: 8.0731 - mape: 29.2157 - val_loss: 8.5085 - val_mape: 41.6575
# Epoch 29/50
# 10/10 [==============================] - 0s 6ms/step - loss: 7.4199 - mape: 28.1544 - val_loss: 6.8877 - val_mape: 27.7895
# Epoch 30/50
# 10/10 [==============================] - 0s 6ms/step - loss: 6.3902 - mape: 24.2668 - val_loss: 7.2948 - val_mape: 31.3665
# Epoch 31/50
# 10/10 [==============================] - 0s 5ms/step - loss: 5.1088 - mape: 20.4630 - val_loss: 5.9023 - val_mape: 25.9752
# Epoch 32/50
# 10/10 [==============================] - 0s 8ms/step - loss: 3.8047 - mape: 15.8426 - val_loss: 4.9362 - val_mape: 22.9362
# Epoch 33/50
# 10/10 [==============================] - 0s 7ms/step - loss: 3.1773 - mape: 13.3796 - val_loss: 3.9130 - val_mape: 17.5768
# Epoch 34/50
# 10/10 [==============================] - 0s 8ms/step - loss: 2.9795 - mape: 12.6701 - val_loss: 5.0511 - val_mape: 25.7494
# Epoch 35/50
# 10/10 [==============================] - 0s 6ms/step - loss: 3.1201 - mape: 13.6244 - val_loss: 4.6806 - val_mape: 23.7034
# Epoch 36/50
# 10/10 [==============================] - 0s 7ms/step - loss: 2.8195 - mape: 12.4056 - val_loss: 3.9981 - val_mape: 20.0466
# Epoch 37/50
# 10/10 [==============================] - 0s 6ms/step - loss: 2.9255 - mape: 12.9507 - val_loss: 4.1953 - val_mape: 20.8183
# Epoch 38/50
# 10/10 [==============================] - 0s 7ms/step - loss: 2.8266 - mape: 12.2224 - val_loss: 4.9972 - val_mape: 25.4298
# Epoch 39/50
# 10/10 [==============================] - 0s 6ms/step - loss: 2.9627 - mape: 12.9843 - val_loss: 6.7285 - val_mape: 36.1369
# Epoch 40/50
# 10/10 [==============================] - 0s 6ms/step - loss: 2.8762 - mape: 12.5089 - val_loss: 6.3420 - val_mape: 33.8102
# Epoch 41/50
# 10/10 [==============================] - 0s 8ms/step - loss: 2.8788 - mape: 12.4719 - val_loss: 6.1013 - val_mape: 32.0949
# Epoch 42/50
# 10/10 [==============================] - 0s 7ms/step - loss: 2.9604 - mape: 12.8148 - val_loss: 4.6317 - val_mape: 23.3304
# Epoch 43/50
# 10/10 [==============================] - 0s 5ms/step - loss: 2.8813 - mape: 12.5529 - val_loss: 4.8078 - val_mape: 24.2685
# Epoch 44/50
# 10/10 [==============================] - 0s 6ms/step - loss: 2.8359 - mape: 12.4460 - val_loss: 5.8916 - val_mape: 31.3701
# Epoch 45/50
# 10/10 [==============================] - 0s 6ms/step - loss: 2.9433 - mape: 12.9436 - val_loss: 4.7938 - val_mape: 24.5869
# Epoch 46/50
# 10/10 [==============================] - 0s 6ms/step - loss: 2.8420 - mape: 12.4156 - val_loss: 3.7928 - val_mape: 17.8855
# Epoch 47/50
# 10/10 [==============================] - 0s 6ms/step - loss: 2.7969 - mape: 12.2478 - val_loss: 3.5553 - val_mape: 15.4856
# Epoch 48/50
# 10/10 [==============================] - 0s 5ms/step - loss: 2.8927 - mape: 12.5450 - val_loss: 5.7877 - val_mape: 30.5857
# Epoch 49/50
# 10/10 [==============================] - 0s 11ms/step - loss: 2.8641 - mape: 12.4687 - val_loss: 5.6038 - val_mape: 30.2219
# Epoch 50/50
# 10/10 [==============================] - 0s 10ms/step - loss: 2.8854 - mape: 12.3596 - val_loss: 6.0499 - val_mape: 33.0731

# %%
history_df = pd.DataFrame(history.history)
history_df.head()
# Out:
#         loss       mape   val_loss    val_mape
# 0  21.460926  85.445274  40.598106  247.787674
# 1  20.203268  78.120148  28.019701  172.369827
# 2  19.482117  74.422935  15.932463   90.415642
# 3  18.900770  71.514771  12.067466   58.219913
# 4  18.235691  68.083794  10.773306   45.369610

# %%
history_df.loc[:, ['loss', 'val_loss']].plot()
history_df.loc[:, ['mape', 'val_mape']].plot()
plt.show()
